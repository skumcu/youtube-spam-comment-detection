# %%
import pandas as pd 
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB
data = pd.read_csv(r"C:\Users\sena\OneDrive - erbakan.edu.tr\Masaüstü\btk_veri_set\Youtube01-Psy.csv")
print(data.sample(5))
# Out:
#                                 COMMENT_ID         AUTHOR  \
# 341      z13qyxk5tzq1e5asx22xjt3wdq3ns32f5  Ameenk Chanel
# 193    z130xbcwfnj5vlskv23airsxqqfqvhl5504      Adam Mudd
# 10   z13auhww3oufjn1qo04ci3grqqjmfjexxuo0k      Huckyduck
# 150      z12mzferzsanzhld022fhhdarrusivwkq          marye
# 205    z121yttbfpyxw1dya04cgtq4clasebvoib4  Vitor Belliny
#
#                     DATE                                            CONTENT  \
# 341  2014-11-14T11:50:02  Free my apps get 1m crdits ! Just click on the...
# 193  2014-11-07T12:16:08  How are there 2 billion views and theres only ...
# 10   2013-11-28T17:06:17                               Hey subscribe to me﻿
# 150  2014-11-06T04:42:33                            Oppa! Yeah! Best Song!﻿
# 205  2014-11-07T15:43:29             2.126.521.750  views!!!!!!!!!!!!!!!!!﻿
#
#      CLASS
# 341      1
# 193      0
# 10       1
# 150      0
# 205      0

# %%
data = data[["CONTENT", "CLASS"]]
print(data.sample(5))
# Out:
#                                                CONTENT  CLASS
# 225  You think you're smart?        Headbutt your f...      0
# 296  If i reach 100 subscribers i will tazz my self...      1
# 214               Still watching this 2 years later? ﻿      0
# 123                          2,124923004 wiews... wow﻿      0
# 134                              ❤️ ❤️ ❤️ ❤️ ❤️❤️❤️❤️﻿      0

# %%
data["CLASS"] = data["CLASS"].map({0:"Spam Değil",1:"Spam"})
print(data.sample(5))
# Out:
#                                                CONTENT       CLASS
# 272                            How stupid humanity is﻿  Spam Değil
# 269  1 millioon dislikessssssssssssssssssssssssssss...  Spam Değil
# 191  The Guy in the yellow suit kinda looks like Ja...  Spam Değil
# 300  Follow 4 Follow                           @ Va...        Spam
# 142  pls http://www10.vakinha.com.br/VaquinhaE.aspx...        Spam

# %%
x = np.array(data["CONTENT"])
y = np.array(data["CLASS"])
cv = CountVectorizer()
x = cv.fit_transform(x)
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)
model = BernoulliNB()
model.fit(xtrain, ytrain)
print(model.score(xtest, ytest))
# Out:
# 0.9857142857142858

# %%
sample = " Follow 4 Follow "
data = cv.transform([sample]).toarray()
print(model.predict(data))
# Out:
# ['Spam Değil']
